# %%
import os
import pandas as pd
import openai
from tenacity import retry, stop_after_attempt, wait_random_exponential
from tqdm import tqdm
import time

# Set your OpenAI API key here
openai.api_key = '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'

# # show working directory
# os.getcwd()

# # change working directory
os.chdir('C:/Users/Soren/Documents/GitHub/IntroSocial23/Exam final/Data collection/News data')

# Loading csv file with data
news_final = pd.read_csv('News_split_soren.csv')
#,sep = ';', encoding = 'utf-8')

# Sorting by company name and reseting index
news_final = news_final.sort_values(by=['date','company']).reset_index(drop = True)

# list of headlines
headlines_list = news_final['title'].astype(str)

# Using a list comprehension to replace ';' in titles
titles_replace_list = [headlines.replace(';', ' ') for headlines in headlines_list]

# Update the 'title' column
news_final['title'] = titles_replace_list


# Data filtering for testing
news_df9 = news_final

# %%
# 180k
# news_df_split = news_df[6550:]

# # 173782
# news_df_split_2 = news_df_split.reset_index(drop=True)

# # 86891
# news_df_split_final_seb = news_df_split_2[:86891]

# # 86892
# news_df_split_final_søren = news_df_split_2[86891:]

# news_df_split_final_seb.to_csv('news_df_split_final_seb.csv', index = False)
# news_df_split_final_søren.to_csv('news_df_split_final_søren.csv', index = False)

# news_df2 = news_df_split_final_søren.reset_index(drop=True)
# news_df2
# Out:
#                             date  \
# 0      2022-12-22T11:00:37+00:00
# 1      2022-12-22T11:00:42+00:00
# 2      2022-12-22T11:00:42+00:00
# 3      2022-12-22T11:00:42+00:00
# 4      2022-12-22T11:00:42+00:00
# ...                          ...
# 86887  2023-06-01T23:44:33+00:00
# 86888  2023-06-01T23:44:33+00:00
# 86889  2023-06-01T23:52:40+00:00
# 86890  2023-06-01T23:52:40+00:00
# 86891  2023-06-01T23:52:40+00:00
#
#                                                    title  \
# 0      Is Broadcom Inc. (NASDAQ:AVGO) A High Quality ...
# 1                   7 Drug Stocks That Will Soar in 2023
# 2                   7 Drug Stocks That Will Soar in 2023
# 3                   7 Drug Stocks That Will Soar in 2023
# 4                   7 Drug Stocks That Will Soar in 2023
# ...                                                  ...
# 86887  Hackers use flaw in popular file transfer tool...
# 86888  Hackers use flaw in popular file transfer tool...
# 86889    The 7 Best Stocks Under $15 to Buy in June 2023
# 86890    The 7 Best Stocks Under $15 to Buy in June 2023
# 86891    The 7 Best Stocks Under $15 to Buy in June 2023
#
#                                                  symbols  \
# 0                               ['AVGO.US', 'AVGO34.SA']
# 1      ['2Y3.F', '5VT.F', 'BNGO.US', 'GLAXF.US', 'GLA...
# 2      ['2Y3.F', '5VT.F', 'BNGO.US', 'GLAXF.US', 'GLA...
# 3      ['2Y3.F', '5VT.F', 'BNGO.US', 'GLAXF.US', 'GLA...
# 4      ['2Y3.F', '5VT.F', 'BNGO.US', 'GLAXF.US', 'GLA...
# ...                                                  ...
# 86887            ['PGR.F', 'PRGS.US', 'R7D.F', 'RPD.US']
# 86888            ['PGR.F', 'PRGS.US', 'R7D.F', 'RPD.US']
# 86889  ['1VPA.F', 'ASTL.US', 'CPRX.US', 'DVAX.US', 'D...
# 86890  ['1VPA.F', 'ASTL.US', 'CPRX.US', 'DVAX.US', 'D...
# 86891  ['1VPA.F', 'ASTL.US', 'CPRX.US', 'DVAX.US', 'D...
#
#                                                sentiment ticker  \
# 0      {'polarity': 0.998, 'neg': 0.053, 'neu': 0.786...   AVGO
# 1      {'polarity': 0.999, 'neg': 0.029, 'neu': 0.857...   BNGO
# 2      {'polarity': 0.999, 'neg': 0.029, 'neu': 0.857...   MDGL
# 3      {'polarity': 0.999, 'neg': 0.029, 'neu': 0.857...   SDGR
# 4      {'polarity': 0.999, 'neg': 0.029, 'neu': 0.857...   ICAD
# ...                                                  ...    ...
# 86887  {'polarity': -0.956, 'neg': 0.105, 'neu': 0.82...   PRGS
# 86888  {'polarity': -0.956, 'neg': 0.105, 'neu': 0.82...    RPD
# 86889  {'polarity': 1, 'neg': 0.011, 'neu': 0.847, 'p...   CPRX
# 86890  {'polarity': 1, 'neg': 0.011, 'neu': 0.847, 'p...   DVAX
# 86891  {'polarity': 1, 'neg': 0.011, 'neu': 0.847, 'p...   VYGR
#
#                                                company
# 0                                         Broadcom Inc
# 1                                 Bionano Genomics Inc
# 2                         Madrigal Pharmaceuticals Inc
# 3                                      Schrodinger Inc
# 4                                             iCAD Inc
# ...                                                ...
# 86887  Progress Software Corporation Common Stock (DE)
# 86888                                       Rapid7 Inc
# 86889                     Catalyst Pharmaceuticals Inc
# 86890    Dynavax Technologies Corporation Common Stock
# 86891                         Voyager Therapeutics Inc
#
# [86892 rows x 6 columns]

# %%
# news_df3 = news_df2[893:]

# news_df3

# news_df4 = news_df3[2559:]
# news_df4

# news_df5 = news_df4[139:]

# news_df6 = news_df5[1791:]
# news_df7 = news_df6[3009:]

# news_df8 = news_df7[1204:] 

# news_df9 = news_df8[47588:]
# news_df9
# Out:
#                             date  \
# 57183  2023-04-19T15:06:01+00:00
# 57184  2023-04-19T15:06:01+00:00
# 57185  2023-04-19T15:10:00+00:00
# 57186  2023-04-19T15:11:28+00:00
# 57187  2023-04-19T15:11:35+00:00
# ...                          ...
# 86887  2023-06-01T23:44:33+00:00
# 86888  2023-06-01T23:44:33+00:00
# 86889  2023-06-01T23:52:40+00:00
# 86890  2023-06-01T23:52:40+00:00
# 86891  2023-06-01T23:52:40+00:00
#
#                                                    title  \
# 57183  Google Says It Hit Leadership Diversity Goals ...
# 57184  Google Says It Hit Leadership Diversity Goals ...
# 57185  Progyny and Fertility Matters Canada Honour Ca...
# 57186  Apple’s Cook Meets India’s Modi, Commits to In...
# 57187  Some Shareholders Feeling Restless Over Kymera...
# ...                                                  ...
# 86887  Hackers use flaw in popular file transfer tool...
# 86888  Hackers use flaw in popular file transfer tool...
# 86889    The 7 Best Stocks Under $15 to Buy in June 2023
# 86890    The 7 Best Stocks Under $15 to Buy in June 2023
# 86891    The 7 Best Stocks Under $15 to Buy in June 2023
#
#                                                  symbols  \
# 57183  ['ABEA.F', 'ABEA.XETRA', 'ABEC.F', 'ABEC.XETRA...
# 57184  ['ABEA.F', 'ABEA.XETRA', 'ABEC.F', 'ABEC.XETRA...
# 57185                                        ['PGNY.US']
# 57186  ['AAPL.MX', 'AAPL.US', 'AAPL34.SA', 'APC.F', '...
# 57187                                        ['KYMR.US']
# ...                                                  ...
# 86887            ['PGR.F', 'PRGS.US', 'R7D.F', 'RPD.US']
# 86888            ['PGR.F', 'PRGS.US', 'R7D.F', 'RPD.US']
# 86889  ['1VPA.F', 'ASTL.US', 'CPRX.US', 'DVAX.US', 'D...
# 86890  ['1VPA.F', 'ASTL.US', 'CPRX.US', 'DVAX.US', 'D...
# 86891  ['1VPA.F', 'ASTL.US', 'CPRX.US', 'DVAX.US', 'D...
#
#                                                sentiment ticker  \
# 57183  {'polarity': -0.861, 'neg': 0.067, 'neu': 0.87...   GOOG
# 57184  {'polarity': -0.861, 'neg': 0.067, 'neu': 0.87...  GOOGL
# 57185  {'polarity': 0.999, 'neg': 0.016, 'neu': 0.786...   PGNY
# 57186  {'polarity': 0.964, 'neg': 0.041, 'neu': 0.862...   AAPL
# 57187  {'polarity': 0.993, 'neg': 0.051, 'neu': 0.834...   KYMR
# ...                                                  ...    ...
# 86887  {'polarity': -0.956, 'neg': 0.105, 'neu': 0.82...   PRGS
# 86888  {'polarity': -0.956, 'neg': 0.105, 'neu': 0.82...    RPD
# 86889  {'polarity': 1, 'neg': 0.011, 'neu': 0.847, 'p...   CPRX
# 86890  {'polarity': 1, 'neg': 0.011, 'neu': 0.847, 'p...   DVAX
# 86891  {'polarity': 1, 'neg': 0.011, 'neu': 0.847, 'p...   VYGR
#
#                                                company
# 57183                                     Alphabet Inc
# 57184                                     Alphabet Inc
# 57185                                      Progyny Inc
# 57186                                        Apple Inc
# 57187                          Kymera Therapeutics Inc
# ...                                                ...
# 86887  Progress Software Corporation Common Stock (DE)
# 86888                                       Rapid7 Inc
# 86889                     Catalyst Pharmaceuticals Inc
# 86890    Dynavax Technologies Corporation Common Stock
# 86891                         Voyager Therapeutics Inc
#
# [29709 rows x 6 columns]

# %%
# Log function
def log(logfile, Index, titles,companys,dates=os.getcwd()):
    # Open or create the csv file
    if os.path.isfile(logfile): #If the log file exists, open it and allow for changes     
        log = open(logfile,'a')
    else: #If the log file does not exist, create it and make headers for the log variables
        log = open(logfile,'w')
        header = ['Timestamp','Index','Title','Company','Dates']
        log.write(';'.join(header) + "\n") #Make the headers and jump to new line
        
    timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())) #Local time
    
    # Open the log file and append the gathered log information
    with open(logfile,'a') as log:
        log.write(f'{timestamp};{Index};{titles};{companys};{dates}' + "\n") #Append the information and jump to new line

# Backoff function 
@retry(wait=wait_random_exponential(min=1, max=60), stop=stop_after_attempt(6))
def completion_with_backoff(**kwargs):
    return openai.ChatCompletion.create(**kwargs)

# %%
# Getting the sentiment analysis from Open AI API

def OpenAI_sentiment(titles, companys, dates):
    responses = []
    index = []
    dates_list = []
    company_list = []
    logfile = 'log_chat_gpt2.csv'
    count = 0
    # 
    for title, company, date in tqdm(zip(titles, companys, dates), desc = 'Analyzing sentiments'):
        response = completion_with_backoff(
                    model='gpt-3.5-turbo',
                    messages=[{'role': 'user', 'content': f'Forget all your previous instructions. Pretend you are a financial expert. You are a financial expert with stock recommendation experience. Answer only “1” if good news, “-1” if bad news, or “0” if uncertain in the first line. Is this headline good or bad for the stock price of {company} in the short term? Headline: {title}'}],
                    temperature=0,
                    max_tokens=2
                )
        sentiment = response['choices'][0]['message']['content']
        index.append(count)
        responses.append(sentiment)
        dates_list.append(date)
        company_list.append(company)
        

        # index responses from dict to dataframe
        Indexed_responses_df = pd.DataFrame.from_dict({'Index': index, 'LLM_score': responses})
        Indexed_responses_df['date'] = dates_list
        Indexed_responses_df['company'] = company_list
        # Making a dataframe with index = index and column = the list of responses
        Indexed_responses_df = Indexed_responses_df.set_index('Index')
        # Save dataframe to csv
        Indexed_responses_df.to_csv('Open AI responses_3_Søren.csv', index=False)
        # Log the response
        log(logfile, count, title, company, date)
        
        count = count + 1
    # Log the response
    time.sleep(0.1)    
    return Indexed_responses_df
            

# Load titles and companies from your data source
titles = news_df9['title']
companys = news_df9['company']
dates = news_df9['date']

# Finding the sentiment of the titles
sentiment_df = OpenAI_sentiment(titles, companys, dates)
# Out:
# Analyzing sentiments: 0it [00:00, ?it/s]
# Analyzing sentiments: 11467it [2:45:00,  1.16it/s]

# %%
sentiment_df
# Out:
#       LLM_score                       date  \
# Index
# 0             1  2022-06-01T00:53:45+00:00
# 1             0  2022-06-01T02:27:00+00:00
# 2             0  2022-06-01T03:50:00+00:00
# 3             0  2022-06-01T03:57:00+00:00
# 4             0  2022-06-01T04:00:30+00:00
# 5            -1  2022-06-01T04:30:00+00:00
# 6            -1  2022-06-01T04:30:00+00:00
# 7            -1  2022-06-01T04:30:00+00:00
# 8            -1  2022-06-01T04:30:00+00:00
# 9            -1  2022-06-01T04:30:00+00:00
# 10           -1  2022-06-01T04:30:00+00:00
# 11           -1  2022-06-01T04:30:00+00:00
# 12            0  2022-06-01T05:14:00+00:00
# 13            0  2022-06-01T06:30:00+00:00
# 14            1  2022-06-01T07:00:00+00:00
# 15            1  2022-06-01T07:30:00+00:00
# 16           -1  2022-06-01T08:04:45+00:00
# 17           -1  2022-06-01T08:04:45+00:00
# 18           -1  2022-06-01T08:32:59+00:00
# 19            1  2022-06-01T09:00:00+00:00
# 20           -1  2022-06-01T09:27:24+00:00
# 21           -1  2022-06-01T09:30:00+00:00
# 22            0  2022-06-01T09:59:00+00:00
# 23            0  2022-06-01T10:00:00+00:00
# 24            0  2022-06-01T10:00:00+00:00
# 25            0  2022-06-01T10:00:00+00:00
# 26            1  2022-06-01T10:00:00+00:00
# 27            1  2022-06-01T10:00:00+00:00
# 28            0  2022-06-01T10:00:00+00:00
# 29            0  2022-06-01T10:00:00+00:00
#
#                                            company
# Index
# 0                               Riot Platforms Inc
# 1                           Forrester Research Inc
# 2                              Jack In The Box Inc
# 3                                         Lyft Inc
# 4                                    Ambarella Inc
# 5                          Axsome Therapeutics Inc
# 6                                       CareDx Inc
# 7                              DENTSPLY SIRONA Inc
# 8                                       Natera Inc
# 9                                         Okta Inc
# 10                                 Pegasystems Inc
# 11                            Upstart Holdings Inc
# 12                                 Pegasystems Inc
# 13                            Booking Holdings Inc
# 14                    Walgreens Boots Alliance Inc
# 15         Appian Corporation Class A Common Stock
# 16                                   Ambarella Inc
# 17                                     Warner Bros
# 18                            Tradeweb Markets Inc
# 19     Heritage Financial Corporation Common Stock
# 20                                    Synopsys Inc
# 21                             Affirm Holdings Inc
# 22                                      Conn's Inc
# 23                                    Biodesix Inc
# 24              Cogent Communications Holdings Inc
# 25                                      Conn's Inc
# 26                                      DexCom Inc
# 27          Landsea Homes Corporation Common Stock
# 28                         New Fortress Energy Inc
# 29                                     Progyny Inc

# %%
# Merging news_df with sentiment_df on index
news_final = pd.merge(news_df, sentiment_df, left_index=True, right_index=True, how='left')

# Creating a csv file with the merged dataframes for further processing
# news_final.to_csv('news_final.csv')

news_final
# Out:
#                        date_x  \
# 0   2022-06-01T00:53:45+00:00
# 1   2022-06-01T02:27:00+00:00
# 2   2022-06-01T03:50:00+00:00
# 3   2022-06-01T03:57:00+00:00
# 4   2022-06-01T04:00:30+00:00
# 5   2022-06-01T04:30:00+00:00
# 6   2022-06-01T04:30:00+00:00
# 7   2022-06-01T04:30:00+00:00
# 8   2022-06-01T04:30:00+00:00
# 9   2022-06-01T04:30:00+00:00
# 10  2022-06-01T04:30:00+00:00
# 11  2022-06-01T04:30:00+00:00
# 12  2022-06-01T05:14:00+00:00
# 13  2022-06-01T06:30:00+00:00
# 14  2022-06-01T07:00:00+00:00
# 15  2022-06-01T07:30:00+00:00
# 16  2022-06-01T08:04:45+00:00
# 17  2022-06-01T08:04:45+00:00
# 18  2022-06-01T08:32:59+00:00
# 19  2022-06-01T09:00:00+00:00
# 20  2022-06-01T09:27:24+00:00
# 21  2022-06-01T09:30:00+00:00
# 22  2022-06-01T09:59:00+00:00
# 23  2022-06-01T10:00:00+00:00
# 24  2022-06-01T10:00:00+00:00
# 25  2022-06-01T10:00:00+00:00
# 26  2022-06-01T10:00:00+00:00
# 27  2022-06-01T10:00:00+00:00
# 28  2022-06-01T10:00:00+00:00
# 29  2022-06-01T10:00:00+00:00
#
#                                                 title  \
# 0   Nomura M&amp A Banker Chung Joins Crypto Firm ...
# 1   Forrester: Only 28% Of Australians Trust The F...
# 2   Jack in the Box to Present at Investor Confere...
# 3   Seattle OKs minimum wage for delivery gig workers
# 4   Ambarella (AMBA) Q1 2023 Earnings Call Transcript
# 5   AXSOME THERAPEUTICS, INC. (NASDAQ: AXSM) SHARE...
# 6   CareDx, Inc. (NASDAQ: CDNA) SHAREHOLDER CLASS ...
# 7   DENTSPLY SIRONA INC. INVESTIGATION ALERT: Bern...
# 8   NATERA, INC. (NASDAQ: NTRA) SHAREHOLDER CLASS ...
# 9   OKTA INC. (NASDAQ: OKTA) SHAREHOLDER CLASS ACT...
# 10  PEGASYSTEMS INC. (NASDAQ: PEGA) SHAREHOLDER CL...
# 11  UPSTART HOLDINGS, INC. (NASDAQ: UPST) SHAREHOL...
# 12  PEGA Investor News: Robbins LLP Reminds Shareh...
# 13  Discounts on Last-Minute Short-Term Rentals Co...
# 14  VF, Best Buy, Walgreen, and 3M Join S&amp P 50...
# 15  Appian Opens New Technology Innovation Center ...
# 16  Salesforce, Victoria's Secret, Capri Rise Prem...
# 17  Salesforce, Victoria's Secret, Capri Rise Prem...
# 18  Pool of negative-yielding European bonds shran...
# 19  Heritage Bank announces new commercial and rel...
# 20  Beijing Says US Supply Chain Curbs Sabotage Ch...
# 21  Missed Payments, Rising Interest Rates Put ‘Bu...
# 22  Conn's, Inc. and Belk Announce Strategic Partn...
# 23  Biodesix to Present at the 42nd Annual William...
# 24  SHAREHOLDER ALERT: Morris Kandinov Investigati...
# 25  Conn’s, Inc. Reports First Quarter Fiscal Year...
# 26  Prince Edward Island Becomes a National Leader...
# 27  Landsea Homes Agrees to Repurchase $30 Million...
# 28  NFE and EBRASIL Agree to Sell the 1.6 GW CELSE...
# 29  SHAREHOLDER ALERT: Morris Kandinov Investigati...
#
#                                               symbols  \
# 0   ['0R01.LSE', 'BK.US', 'BN9.F', 'BONY34.SA', 'C...
# 1                                         ['FORR.US']
# 2                                ['JACK.US', 'JBX.F']
# 3   ['DASH.US', 'LY0.F', 'LYFT.US', 'U1BE34.SA', '...
# 4                                ['A8B.F', 'AMBA.US']
# 5                                         ['AXSM.US']
# 6                                         ['CDNA.US']
# 7                                         ['XRAY.US']
# 8                                         ['NTRA.US']
# 9                                         ['OKTA.US']
# 10                                        ['PEGA.US']
# 11                                        ['UPST.US']
# 12                                        ['PEGA.US']
# 13      ['ABNB.US', 'BKNG.US', 'BKNG34.SA', 'PCE1.F']
# 14  ['BBK.F', 'BEN.US', 'FRK.F', 'TFC-PR.US', 'TFC...
# 15                   ['910.F', 'APPN.US', 'PGUAX.US']
# 16  ['7HP.F', '7HP.STU', '7HP.XETRA', 'A8B.F', 'AM...
# 17  ['7HP.F', '7HP.STU', '7HP.XETRA', 'A8B.F', 'AM...
# 18                                          ['TW.US']
# 19                                        ['HFWA.US']
# 20          ['0981.HK', 'MKN2.F', 'SNPS.US', 'SYP.F']
# 21                                        ['AFRM.US']
# 22                                        ['CONN.US']
# 23                                        ['BDSX.US']
# 24                  ['CCOI.US', 'PGNY.US', 'STON.US']
# 25                               ['CN4.F', 'CONN.US']
# 26                               ['DC4.F', 'DXCM.US']
# 27                                        ['LSEA.US']
# 28                                         ['NFE.US']
# 29                  ['CCOI.US', 'PGNY.US', 'STON.US']
#
#                                             sentiment ticker  \
# 0   {'polarity': -0.955, 'neg': 0.094, 'neu': 0.84...   RIOT
# 1   {'polarity': 1, 'neg': 0.026, 'neu': 0.726, 'p...   FORR
# 2   {'polarity': 0.823, 'neg': 0, 'neu': 0.961, 'p...   JACK
# 3   {'polarity': 0.178, 'neg': 0, 'neu': 0.904, 'p...   LYFT
# 4   {'polarity': 0.859, 'neg': 0.02, 'neu': 0.816,...   AMBA
# 5   {'polarity': 0.992, 'neg': 0.035, 'neu': 0.874...   AXSM
# 6   {'polarity': 0.988, 'neg': 0.045, 'neu': 0.866...   CDNA
# 7   {'polarity': 0.982, 'neg': 0.022, 'neu': 0.896...   XRAY
# 8   {'polarity': 0.995, 'neg': 0.047, 'neu': 0.85,...   NTRA
# 9   {'polarity': 0.949, 'neg': 0.059, 'neu': 0.857...   OKTA
# 10  {'polarity': 0.978, 'neg': 0.05, 'neu': 0.866,...   PEGA
# 11  {'polarity': 0.98, 'neg': 0.056, 'neu': 0.839,...   UPST
# 12  {'polarity': -0.875, 'neg': 0.098, 'neu': 0.82...   PEGA
# 13  {'polarity': 0.996, 'neg': 0.032, 'neu': 0.884...   BKNG
# 14      {'polarity': 0, 'neg': 0, 'neu': 1, 'pos': 0}    WBA
# 15  {'polarity': 0.998, 'neg': 0.006, 'neu': 0.851...   APPN
# 16  {'polarity': 0.884, 'neg': 0.05, 'neu': 0.86, ...   AMBA
# 17  {'polarity': 0.884, 'neg': 0.05, 'neu': 0.86, ...    WBD
# 18  {'polarity': -0.872, 'neg': 0.082, 'neu': 0.89...     TW
# 19  {'polarity': 0.987, 'neg': 0, 'neu': 0.851, 'p...   HFWA
# 20  {'polarity': -0.961, 'neg': 0.1, 'neu': 0.849,...   SNPS
# 21      {'polarity': 0, 'neg': 0, 'neu': 1, 'pos': 0}   AFRM
# 22  {'polarity': 0.997, 'neg': 0, 'neu': 0.884, 'p...   CONN
# 23  {'polarity': -0.557, 'neg': 0.057, 'neu': 0.88...   BDSX
# 24  {'polarity': 0.673, 'neg': 0.061, 'neu': 0.86,...   CCOI
# 25  {'polarity': 1, 'neg': 0.057, 'neu': 0.828, 'p...   CONN
# 26  {'polarity': 0.997, 'neg': 0.01, 'neu': 0.906,...   DXCM
# 27  {'polarity': 0.992, 'neg': 0.047, 'neu': 0.848...   LSEA
# 28  {'polarity': 0.997, 'neg': 0.036, 'neu': 0.862...    NFE
# 29  {'polarity': 0.673, 'neg': 0.061, 'neu': 0.86,...   PGNY
#
#                                       company_x LLM_score  \
# 0                            Riot Platforms Inc         1
# 1                        Forrester Research Inc         0
# 2                           Jack In The Box Inc         0
# 3                                      Lyft Inc         0
# 4                                 Ambarella Inc         0
# 5                       Axsome Therapeutics Inc        -1
# 6                                    CareDx Inc        -1
# 7                           DENTSPLY SIRONA Inc        -1
# 8                                    Natera Inc        -1
# 9                                      Okta Inc        -1
# 10                              Pegasystems Inc        -1
# 11                         Upstart Holdings Inc        -1
# 12                              Pegasystems Inc         0
# 13                         Booking Holdings Inc         0
# 14                 Walgreens Boots Alliance Inc         1
# 15      Appian Corporation Class A Common Stock         1
# 16                                Ambarella Inc        -1
# 17                                  Warner Bros        -1
# 18                         Tradeweb Markets Inc        -1
# 19  Heritage Financial Corporation Common Stock         1
# 20                                 Synopsys Inc        -1
# 21                          Affirm Holdings Inc        -1
# 22                                   Conn's Inc         0
# 23                                 Biodesix Inc         0
# 24           Cogent Communications Holdings Inc         0
# 25                                   Conn's Inc         0
# 26                                   DexCom Inc         1
# 27       Landsea Homes Corporation Common Stock         1
# 28                      New Fortress Energy Inc         0
# 29                                  Progyny Inc         0
#
#                        date_y                                    company_y
# 0   2022-06-01T00:53:45+00:00                           Riot Platforms Inc
# 1   2022-06-01T02:27:00+00:00                       Forrester Research Inc
# 2   2022-06-01T03:50:00+00:00                          Jack In The Box Inc
# 3   2022-06-01T03:57:00+00:00                                     Lyft Inc
# 4   2022-06-01T04:00:30+00:00                                Ambarella Inc
# 5   2022-06-01T04:30:00+00:00                      Axsome Therapeutics Inc
# 6   2022-06-01T04:30:00+00:00                                   CareDx Inc
# 7   2022-06-01T04:30:00+00:00                          DENTSPLY SIRONA Inc
# 8   2022-06-01T04:30:00+00:00                                   Natera Inc
# 9   2022-06-01T04:30:00+00:00                                     Okta Inc
# 10  2022-06-01T04:30:00+00:00                              Pegasystems Inc
# 11  2022-06-01T04:30:00+00:00                         Upstart Holdings Inc
# 12  2022-06-01T05:14:00+00:00                              Pegasystems Inc
# 13  2022-06-01T06:30:00+00:00                         Booking Holdings Inc
# 14  2022-06-01T07:00:00+00:00                 Walgreens Boots Alliance Inc
# 15  2022-06-01T07:30:00+00:00      Appian Corporation Class A Common Stock
# 16  2022-06-01T08:04:45+00:00                                Ambarella Inc
# 17  2022-06-01T08:04:45+00:00                                  Warner Bros
# 18  2022-06-01T08:32:59+00:00                         Tradeweb Markets Inc
# 19  2022-06-01T09:00:00+00:00  Heritage Financial Corporation Common Stock
# 20  2022-06-01T09:27:24+00:00                                 Synopsys Inc
# 21  2022-06-01T09:30:00+00:00                          Affirm Holdings Inc
# 22  2022-06-01T09:59:00+00:00                                   Conn's Inc
# 23  2022-06-01T10:00:00+00:00                                 Biodesix Inc
# 24  2022-06-01T10:00:00+00:00           Cogent Communications Holdings Inc
# 25  2022-06-01T10:00:00+00:00                                   Conn's Inc
# 26  2022-06-01T10:00:00+00:00                                   DexCom Inc
# 27  2022-06-01T10:00:00+00:00       Landsea Homes Corporation Common Stock
# 28  2022-06-01T10:00:00+00:00                      New Fortress Energy Inc
# 29  2022-06-01T10:00:00+00:00                                  Progyny Inc

# %%
# Test to see the output of the csv file

# Read the csv file named Open AI responses.csv
OpenAI_df = pd.read_csv('news_final.csv')
OpenAI_df.head()
# Out:
#    Unnamed: 0                     date_x  \
# 0           0  2023-07-27T13:00:00+00:00
# 1           1  2023-07-31T11:30:31+00:00
# 2           2  2023-07-31T13:48:00+00:00
# 3           3  2023-07-27T22:30:25+00:00
# 4           4  2023-07-28T12:13:45+00:00
#
#                                                title  \
# 0  Ansys Accelerates Innovation by Expanding AI O...
# 1  The 3 Best 3D Printing Stocks to Buy Now: July...
# 2  Factors to Note Ahead of ANSYS (ANSS) Q2 Earni...
# 3  7 Semiconductor Stocks to Buy Before the Breakout
# 4  3 Semiconductor Stocks You Better Be Buying on...
#
#                                              content  \
# 0  Ansys invests further in AI with the beta laun...
# 1  2022 was unkind to growth stocks of all stripe...
# 2  ANSYS, Inc ANSS is scheduled to report second-...
# 3  Semiconductor stocks recently received news th...
# 4  Semiconductors are increasingly crucial as our...
#
#                                                 link  \
# 0  https://finance.yahoo.com/news/ansys-accelerat...
# 1  https://finance.yahoo.com/news/3-best-3d-print...
# 2  https://finance.yahoo.com/news/factors-note-ah...
# 3  https://finance.yahoo.com/news/7-semiconductor...
# 4  https://finance.yahoo.com/news/3-semiconductor...
#
#                                              symbols tags  \
# 0                               ['AKX.F', 'ANSS.US']   []
# 1  ['AKX.F', 'ANSS.US', 'FARO.US', 'NNDM.US', 'SS...   []
# 2            ['AKX.F', 'ANSS.US', 'ROK.US', 'RWL.F']   []
# 3  ['2330.TW', 'AAPL.US', 'AMAT.MX', 'AMAT.US', '...   []
# 4  ['AMD.US', 'ASME.F', 'ASME.XETRA', 'ASML.AS', ...   []
#
#                                            sentiment        company_x  \
# 0  {'polarity': 0.999, 'neg': 0.007, 'neu': 0.817...        ANSYS Inc
# 1  {'polarity': 0.998, 'neg': 0.039, 'neu': 0.836...        ANSYS Inc
# 2  {'polarity': 0.997, 'neg': 0.015, 'neu': 0.864...        ANSYS Inc
# 3  {'polarity': 1, 'neg': 0.019, 'neu': 0.835, 'p...  ASML Holding NV
# 4  {'polarity': 0.999, 'neg': 0.029, 'neu': 0.843...  ASML Holding NV
#
#    Response                     date_y        company_y
# 0         1  2023-07-27T13:00:00+00:00        ANSYS Inc
# 1         0  2023-07-31T11:30:31+00:00        ANSYS Inc
# 2         0  2023-07-31T13:48:00+00:00        ANSYS Inc
# 3         1  2023-07-27T22:30:25+00:00  ASML Holding NV
# 4         1  2023-07-28T12:13:45+00:00  ASML Holding NV
